# %%
# Out:
# Running 1000 trials of PREC algorithm...
# Completed 100 runs...
# Completed 200 runs...
# Completed 300 runs...
# Completed 400 runs...
# Completed 500 runs...
# Completed 600 runs...
# Completed 700 runs...
# Completed 800 runs...
# Completed 900 runs...
# Valid solutions: 1000/1000 (100.00%)
# Mean fitness: 24.8103
# Std deviation of fitness: 0.0055
# Mean computation time: 0.1409 seconds
# Std deviation of time: 0.0320 seconds
